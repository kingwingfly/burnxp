# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !curl -LO "https://github.com/kingwingfly/burnxp/releases/download/v0.1.0-alpha27/burnxp-v0.1.0-alpha27-x86_64-unknown-linux-gnu.tar.gz"
# !tar xvf burnxp-v0.1.0-alpha27-x86_64-unknown-linux-gnu.tar.gz
# !rm -rf burnxp burnxp-v0.1.0-alpha27-x86_64-unknown-linux-gnu.tar.gz
# !mv burnxp-v0.1.0-alpha27-x86_64-unknown-linux-gnu burnxp
# !cd burnxp && run/setup.sh
# !cp -a /content/drive/MyDrive/data/tags.json /content/burnxp/tags.json
# !cp -a /content/drive/MyDrive/data/picked /content/burnxp/picked

# %%
# !pip install colab-xterm
# %load_ext colabxterm
# %xterm

# %% [markdown]
# ```bash
# cd burnxp
# export export LD_LIBRARY_PATH="$(pwd)/libtorch/lib:$LD_LIBRARY_PATH" LIBTORCH="$(pwd)/libtorch"
# ./tagger divide tags.json
# ./score train && cp burnxp_artifact/model /content/drive/MyDrive/data
# ```

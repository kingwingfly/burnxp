# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !curl -LO "https://github.com/kingwingfly/burnxp/releases/download/v0.1.0-alpha40/burnxp-v0.1.0-alpha40-x86_64-unknown-linux-gnu.tar.gz"
# !tar xvf burnxp-v0.1.0-alpha40-x86_64-unknown-linux-gnu.tar.gz
# !rm -rf burnxp burnxp-v0.1.0-alpha40-x86_64-unknown-linux-gnu.tar.gz
# !mv burnxp-v0.1.0-alpha40-x86_64-unknown-linux-gnu burnxp
# !cd burnxp && run/setup.sh

# %%
# !cp /content/drive/MyDrive/data/burnxp.tar.gz /content/burnxp
# !cd burnxp && tar xvf burnxp.tar.gz && rm burnxp.tar.gz && ls

# %%
# !cd burnxp && export export LD_LIBRARY_PATH="$(pwd)/libtorch/lib:$LD_LIBRARY_PATH" LIBTORCH="$(pwd)/libtorch" && ./tagger divide tags.json && ./burnxp train -b 4 -w 2 -l 0.001 && cp burnxp_artifact/model.mpk /content/drive/MyDrive/data

# %%
# !pip install colab-xterm
# %load_ext colabxterm
# %xterm

# %% [markdown]
# ```bash
# cd burnxp
# export export LD_LIBRARY_PATH="$(pwd)/libtorch/lib:$LD_LIBRARY_PATH" LIBTORCH="$(pwd)/libtorch"
# ./tagger divide tags.json
# ./burnxp train -b 4 -w 2 && cp burnxp_artifact/model.mpk /content/drive/MyDrive/data
# ```
